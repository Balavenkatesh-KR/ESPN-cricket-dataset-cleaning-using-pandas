# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('cricketTestMatchData.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %%
df.head()
# Out:
#              Player       Span Mat  Inns  NO  Runs    HS    Ave     BF     SR  \
# 0  DG Bradman (AUS)  1928-1948  52    80  10  6996   334  99.94  9800+  58.60
# 1    HC Brook (ENG)  2022-2023  12    20   1  1181   186  62.15   1287  91.76
# 2    AC Voges (AUS)  2015-2016  20    31   7  1485  269*  61.87   2667  55.68
# 3   RG Pollock (SA)  1963-1970  23    41   4  2256   274  60.97  1707+  54.48
# 4   GA Headley (WI)  1930-1954  22    40   4  2190  270*  60.83   416+  56.00
#
#    100  50  0   4s  6s
# 0   29  13  7  626   6
# 1    4   7  1  141  23
# 2    5   4  2  186   5
# 3    7  11  1  246  11
# 4   10   5  2  104   1

# %%
df.tail()
# Out:
#                Player       Span  Mat  Inns  NO  Runs   HS    Ave     BF  \
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357  250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265  277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122  266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748  232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296  127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 61  49.16   15  33   4   525  23
# 62  59.67   27  38  11  1165  24
# 63  44.77    7   6   1   119   0
# 64  60.02    6  13   4   241   5
# 65  25.59    1  10   2    53   0

# %%
#renaming

# %%
df=df.rename(columns={'NO':'not_outs','HS':'high_inns_score','BF':'balls_faced','SR':'strike_rate','Mat':'matches'})

# %%
df
# Out:
#                Player       Span matches  Inns  not_outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948      52    80        10  6996
# 1      HC Brook (ENG)  2022-2023      12    20         1  1181
# 2      AC Voges (AUS)  2015-2016      20    31         7  1485
# 3     RG Pollock (SA)  1963-1970      23    41         4  2256
# 4     GA Headley (WI)  1930-1954      22    40         4  2190
# ..                ...        ...     ...   ...       ...   ...
# 61   KD Walters (AUS)  1965-1981      74   125        14  5357
# 62  GC Smith (ICC/SA)  2002-2014     117   205        13  9265
# 63  WH Ponsford (AUS)  1924-1934      29    48         4  2122
# 64    SJ McCabe (AUS)  1930-1938      39    62         5  2748
# 65   DR Jardine (ENG)  1928-1934      22    33         6  1296
#
#    high_inns_score    Ave balls_faced  strike_rate  100  50   0    4s  6s
# 0              334  99.94       9800+        58.60   29  13   7   626   6
# ...

# %%
#check null values

# %%
df.isnull().sum()
# Out:
# Player             0
# Span               0
# matches            0
# Inns               0
# not_outs           0
# Runs               0
# high_inns_score    0
# Ave                0
# balls_faced        3
# strike_rate        3
# 100                0
# 50                 0
# 0                  0
# 4s                 0
# 6s                 0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Player             False
# Span               False
# matches            False
# Inns               False
# not_outs           False
# Runs               False
# high_inns_score    False
# Ave                False
# balls_faced         True
# strike_rate         True
# 100                False
# 50                 False
# 0                  False
# 4s                 False
# 6s                 False
# dtype: bool

# %%
df[df['balls_faced'].isna()==1]
# Out:
#                   Player       Span matches  Inns  not_outs  Runs  \
# 9         ED Weekes (WI)  1948-1958      48    81         5  4455
# 17       CL Walcott (WI)  1948-1960      44    74         7  3798
# 58  Hon.FS Jackson (ENG)  1893-1905      20    33         4  1415
#
#    high_inns_score    Ave balls_faced  strike_rate  100  50  0   4s  6s
# 9              207  58.61         NaN          NaN   15  19  6  258   2
# 17             220  56.68         NaN          NaN   15  14  1  107  11
# 58            144*  48.79         NaN          NaN    5   6  3   51   0

# %%
df['balls_faced']=df['balls_faced'].fillna(0)

# %%
df['strike_rate']=df['strike_rate'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Player             0
# Span               0
# matches            0
# Inns               0
# not_outs           0
# Runs               0
# high_inns_score    0
# Ave                0
# balls_faced        0
# strike_rate        0
# 100                0
# 50                 0
# 0                  0
# 4s                 0
# 6s                 0
# dtype: int64

# %%
#dropping duplicates

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df[df['Player'].duplicated()==1]
# Out:
#              Player       Span matches  Inns  not_outs  Runs high_inns_score  \
# 5   GA Headley (WI)  1930-1954      22    40         4  2190            270*
# 13   GS Sobers (WI)  1954-1974      93   160        21  8032            365*
# 16   JB Hobbs (ENG)  1908-1930      61   102         7  5410             211
# 54    V Kohli (IND)  2011-2024     113   191        11  8848            254*
#
#       Ave balls_faced  strike_rate  100  50   0   4s  6s
# 5   60.83        416+        56.00   10   5   2  104   1
# 13  57.78       4063+        53.58   26  30  12  593  32
# 16  56.94       5363+        46.22   15  28   4  276   8
# 54  49.15       15924        55.56   29  30  14  991  26

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                Player       Span matches  Inns  not_outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948      52    80        10  6996
# 1      HC Brook (ENG)  2022-2023      12    20         1  1181
# 2      AC Voges (AUS)  2015-2016      20    31         7  1485
# 3     RG Pollock (SA)  1963-1970      23    41         4  2256
# 4     GA Headley (WI)  1930-1954      22    40         4  2190
# ..                ...        ...     ...   ...       ...   ...
# 61   KD Walters (AUS)  1965-1981      74   125        14  5357
# 62  GC Smith (ICC/SA)  2002-2014     117   205        13  9265
# 63  WH Ponsford (AUS)  1924-1934      29    48         4  2122
# 64    SJ McCabe (AUS)  1930-1938      39    62         5  2748
# 65   DR Jardine (ENG)  1928-1934      22    33         6  1296
#
#    high_inns_score    Ave balls_faced  strike_rate  100  50   0    4s  6s
# 0              334  99.94       9800+        58.60   29  13   7   626   6
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#splitting span column inton start date and end date

# %%
df['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['rookie_year']=df['Span'].str.split(pat='-').str[0]
# Out:
# C:\Users\asdfghj\AppData\Local\Temp\ipykernel_15696\2903910599.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rookie_year']=df['Span'].str.split(pat='-').str[0]

# %%
df['final_year']=df['Span'].str.split(pat='-').str[1]
# Out:
# C:\Users\asdfghj\AppData\Local\Temp\ipykernel_15696\3395095141.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['final_year']=df['Span'].str.split(pat='-').str[1]

# %%
df
# Out:
#                Player       Span matches  Inns  not_outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948      52    80        10  6996
# 1      HC Brook (ENG)  2022-2023      12    20         1  1181
# 2      AC Voges (AUS)  2015-2016      20    31         7  1485
# 3     RG Pollock (SA)  1963-1970      23    41         4  2256
# 4     GA Headley (WI)  1930-1954      22    40         4  2190
# ..                ...        ...     ...   ...       ...   ...
# 61   KD Walters (AUS)  1965-1981      74   125        14  5357
# 62  GC Smith (ICC/SA)  2002-2014     117   205        13  9265
# 63  WH Ponsford (AUS)  1924-1934      29    48         4  2122
# 64    SJ McCabe (AUS)  1930-1938      39    62         5  2748
# 65   DR Jardine (ENG)  1928-1934      22    33         6  1296
#
#    high_inns_score    Ave balls_faced  strike_rate  100  50   0    4s  6s  \
# 0              334  99.94       9800+        58.60   29  13   7   626   6
# ...

# %%
#drop span column

# %%
df=df.drop('Span',axis=1)

# %%
df
# Out:
#                Player matches  Inns  not_outs  Runs high_inns_score    Ave  \
# 0    DG Bradman (AUS)      52    80        10  6996             334  99.94
# 1      HC Brook (ENG)      12    20         1  1181             186  62.15
# 2      AC Voges (AUS)      20    31         7  1485            269*  61.87
# 3     RG Pollock (SA)      23    41         4  2256             274  60.97
# 4     GA Headley (WI)      22    40         4  2190            270*  60.83
# ..                ...     ...   ...       ...   ...             ...    ...
# 61   KD Walters (AUS)      74   125        14  5357             250  48.26
# 62  GC Smith (ICC/SA)     117   205        13  9265             277  48.25
# 63  WH Ponsford (AUS)      29    48         4  2122             266  48.22
# 64    SJ McCabe (AUS)      39    62         5  2748             232  48.21
# 65   DR Jardine (ENG)      22    33         6  1296             127  48.00
#
# ...

# %%
#splitting country from the player

# %%
df['Player'].str.split(pat='(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 61     [KD Walters , AUS)]
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 64      [SJ McCabe , AUS)]
# 65     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df['country']=df['Player'].str.split(pat='(').str[1]

# %%
df['country']=df['country'].str.split(pat=')').str[0]

# %%
df['country']
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 61       AUS
# 62    ICC/SA
# 63       AUS
# 64       AUS
# 65       ENG
# Name: country, Length: 62, dtype: object

# %%
df['Player']=df['Player'].str.split(pat='(').str[0]

# %%
df
# Out:
#           Player matches  Inns  not_outs  Runs high_inns_score    Ave  \
# 0    DG Bradman       52    80        10  6996             334  99.94
# 1      HC Brook       12    20         1  1181             186  62.15
# 2      AC Voges       20    31         7  1485            269*  61.87
# 3    RG Pollock       23    41         4  2256             274  60.97
# 4    GA Headley       22    40         4  2190            270*  60.83
# ..           ...     ...   ...       ...   ...             ...    ...
# 61   KD Walters       74   125        14  5357             250  48.26
# 62     GC Smith      117   205        13  9265             277  48.25
# 63  WH Ponsford       29    48         4  2122             266  48.22
# 64    SJ McCabe       39    62         5  2748             232  48.21
# 65   DR Jardine       22    33         6  1296             127  48.00
#
#    balls_faced  strike_rate  100  50   0    4s  6s rookie_year final_year  \
# ...

# %%
#changing datatypes

# %%
df.dtypes
# Out:
# Player              object
# matches             object
# Inns                 int64
# not_outs             int64
# Runs                 int64
# high_inns_score     object
# Ave                float64
# balls_faced         object
# strike_rate        float64
# 100                  int64
# 50                   int64
# 0                    int64
# 4s                   int64
# 6s                   int64
# rookie_year         object
# final_year          object
# country             object
# dtype: object

# %%
df['high_inns_score'].str.split(pat='*').str[0]
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: high_inns_score, Length: 62, dtype: object

# %%
df['high_inns_score']=df['high_inns_score'].str.split(pat='*').str[0]

# %%
df['high_inns_score']
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: high_inns_score, Length: 62, dtype: object

# %%
df['high_inns_score']=df['high_inns_score'].astype('int')

# %%
df.dtypes
# Out:
# Player              object
# matches             object
# Inns                 int64
# not_outs             int64
# Runs                 int64
# high_inns_score      int32
# Ave                float64
# balls_faced         object
# strike_rate        float64
# 100                  int64
# 50                   int64
# 0                    int64
# 4s                   int64
# 6s                   int64
# rookie_year         object
# final_year          object
# country             object
# dtype: object

# %%
df['rookie_year']=df['rookie_year'].astype('int')

# %%
df.dtypes
# Out:
# Player              object
# matches             object
# Inns                 int64
# not_outs             int64
# Runs                 int64
# high_inns_score      int32
# Ave                float64
# balls_faced         object
# strike_rate        float64
# 100                  int64
# 50                   int64
# 0                    int64
# 4s                   int64
# 6s                   int64
# rookie_year          int32
# final_year          object
# country             object
# dtype: object

# %%
df['final_year']=df['final_year'].astype('int')

# %%
df.dtypes
# Out:
# Player              object
# matches             object
# Inns                 int64
# not_outs             int64
# Runs                 int64
# high_inns_score      int32
# Ave                float64
# balls_faced         object
# strike_rate        float64
# 100                  int64
# 50                   int64
# 0                    int64
# 4s                   int64
# 6s                   int64
# rookie_year          int32
# final_year           int32
# country             object
# dtype: object

# %%
df.head()
# Out:
#         Player matches  Inns  not_outs  Runs  high_inns_score    Ave  \
# 0  DG Bradman       52    80        10  6996              334  99.94
# 1    HC Brook       12    20         1  1181              186  62.15
# 2    AC Voges       20    31         7  1485              269  61.87
# 3  RG Pollock       23    41         4  2256              274  60.97
# 4  GA Headley       22    40         4  2190              270  60.83
#
#   balls_faced  strike_rate  100  50  0   4s  6s  rookie_year  final_year  \
# 0       9800+        58.60   29  13  7  626   6         1928        1948
# 1        1287        91.76    4   7  1  141  23         2022        2023
# 2        2667        55.68    5   4  2  186   5         2015        2016
# 3       1707+        54.48    7  11  1  246  11         1963        1970
# 4        416+        56.00   10   5  2  104   1         1930        1954
#
#   country
# 0     AUS
# 1     ENG
# 2     AUS
# 3      SA
# 4      WI

# %%
df['matches']=df['matches'].str.split(pat='*').str[0]

# %%
df['matches']=df['matches'].astype('int')

# %%
df.dtypes
# Out:
# Player              object
# matches              int32
# Inns                 int64
# not_outs             int64
# Runs                 int64
# high_inns_score      int32
# Ave                float64
# balls_faced         object
# strike_rate        float64
# 100                  int64
# 50                   int64
# 0                    int64
# 4s                   int64
# 6s                   int64
# rookie_year          int32
# final_year           int32
# country             object
# dtype: object

# %%
df['balls_faced']=df['balls_faced'].str.split(pat='+').str[0]

# %%
df['balls_faced']
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4       416
#       ...
# 61     8662
# 62    15525
# 63     3118
# 64     3217
# 65     2110
# Name: balls_faced, Length: 62, dtype: object

# %%
df.isnull().sum()
# Out:
# Player             0
# matches            0
# Inns               0
# not_outs           0
# Runs               0
# high_inns_score    0
# Ave                0
# balls_faced        3
# strike_rate        0
# 100                0
# 50                 0
# 0                  0
# 4s                 0
# 6s                 0
# rookie_year        0
# final_year         0
# country            0
# dtype: int64

# %%
df[df['balls_faced'].isna()==1]
# Out:
#              Player  matches  Inns  not_outs  Runs  high_inns_score    Ave  \
# 9        ED Weekes        48    81         5  4455              207  58.61
# 17      CL Walcott        44    74         7  3798              220  56.68
# 58  Hon.FS Jackson        20    33         4  1415              144  48.79
#
#    balls_faced  strike_rate  100  50  0   4s  6s  rookie_year  final_year  \
# 9          NaN          0.0   15  19  6  258   2         1948        1958
# 17         NaN          0.0   15  14  1  107  11         1948        1960
# 58         NaN          0.0    5   6  3   51   0         1893        1905
#
#    country
# 9       WI
# 17      WI
# 58     ENG

# %%
df['balls_faced']=df['balls_faced'].fillna(0)

# %%
df['balls_faced']
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4       416
#       ...
# 61     8662
# 62    15525
# 63     3118
# 64     3217
# 65     2110
# Name: balls_faced, Length: 62, dtype: object

# %%
df[df['balls_faced'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, matches, Inns, not_outs, Runs, high_inns_score, Ave, balls_faced, strike_rate, 100, 50, 0, 4s, 6s, rookie_year, final_year, country]
# Index: []

# %%
df['balls_faced']=df['balls_faced'].astype('int')

# %%
df.dtypes
# Out:
# Player              object
# matches              int32
# Inns                 int64
# not_outs             int64
# Runs                 int64
# high_inns_score      int32
# Ave                float64
# balls_faced          int32
# strike_rate        float64
# 100                  int64
# 50                   int64
# 0                    int64
# 4s                   int64
# 6s                   int64
# rookie_year          int32
# final_year           int32
# country             object
# dtype: object

# %%
#building a career length column

# %%
df['career_length']=df['final_year']-df['rookie_year']

# %%
df
# Out:
#           Player  matches  Inns  not_outs  Runs  high_inns_score    Ave  \
# 0    DG Bradman        52    80        10  6996              334  99.94
# 1      HC Brook        12    20         1  1181              186  62.15
# 2      AC Voges        20    31         7  1485              269  61.87
# 3    RG Pollock        23    41         4  2256              274  60.97
# 4    GA Headley        22    40         4  2190              270  60.83
# ..           ...      ...   ...       ...   ...              ...    ...
# 61   KD Walters        74   125        14  5357              250  48.26
# 62     GC Smith       117   205        13  9265              277  48.25
# 63  WH Ponsford        29    48         4  2122              266  48.22
# 64    SJ McCabe        39    62         5  2748              232  48.21
# 65   DR Jardine        22    33         6  1296              127  48.00
#
#     balls_faced  strike_rate  100  50   0    4s  6s  rookie_year  final_year  \
# ...

# %%
df['career_length'].mean()
# Out:
# 13.193548387096774

# %%
#avg batting strike rate for players above 10 years

# %%
df[df['career_length']>10]['strike_rate'].mean()
# Out:
# 47.94909090909091

# %%
#cricketers who played before 1960

# %%
df[df['rookie_year']<1960]["Player"].count()
# Out:
# 23

# %%
# max highest innings score by country

# %%
df.groupby('country')['high_inns_score'].max()
# Out:
# country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: high_inns_score, dtype: int32

# %%
df.groupby('country')['high_inns_score'].max().to_frame('highestincountry').reset_index().sort_values('highestincountry',ascending=False)
# Out:
#     country  highestincountry
# 5    ICC/WI               400
# 0       AUS               380
# 10       SL               374
# 11       WI               365
# 1       ENG               364
# 3   ICC/PAK               329
# 2   ICC/IND               319
# 8       PAK               313
# 9        SA               278
# 4    ICC/SA               277
# 6       IND               254
# 7        NZ               251
# 12      ZIM               232

# %%
#hundreds 50 and ducks avg by country

# %%
df.groupby('country')[['100','50','0']].mean()
# Out:
#                100         50          0
# country
# AUS      20.625000  28.312500   8.500000
# ENG      12.384615  20.769231   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  21.000000   5.500000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
